# %%
import uproot as ur
import matplotlib.pyplot as plt
import numpy as np
import awkward as ak

# %%
# !stashcp stash:///osgconnect/public/yug/remollOutput/remollout.12386286.0.root ./remollout.12386286.0.root

# %%
remollout = ur.open("remollout.12386286.0.root:T;1")
# remollout = ur.open("remollout.12386286.0.root")

remollout.keys()
# remollout.classnames()
# Out:
# ['units',
#  'units/ppm',
#  'units/ppb',
#  'units/nm',
#  'units/um',
#  'units/mm',
#  'units/cm',
#  'units/m',
#  'units/mm2',
#  'units/cm2',
#  'units/m2',
#  'units/mm3',
#  'units/cm3',
#  'units/m3',
#  'units/eV',
#  'units/keV',
#  'units/MeV',
#  'units/GeV',
#  'units/rad',
#  'units/deg',
#  'units/sr',
#  'units/barn',
#  'units/mbarn',
#  'units/ubarn',
#  'units/nsec',
#  'units/msec',
#  'units/sec',
#  'units/Hz',
#  'units/kHz',
#  'units/MHz',
#  'units/GHz',
#  'dets.sd',
#  'dets.lv',
#  'seed',
#  'seed/TObject',
#  'seed/TObject/fUniqueID',
#  'seed/TObject/fBits',
#  'seed/fRunNo',
#  'seed/fEvtNo',
#  'seed/fSeed',
#  'rate',
#  'ev',
#  'ev/A',
#  'ev/Am',
#  'ev/xs',
#  'ev/Q2',
#  'ev/W2',
#  'ev/thcom',
#  'ev/beamp',
#  'bm',
#  'bm/x',
#  'bm/y',
#  'bm/z',
#  'bm/dx',
#  'bm/dy',
#  'bm/dz',
#  'bm/th',
#  'bm/ph',
#  'part',
#  'part/part.pid',
#  'part/part.vx',
#  'part/part.vy',
#  'part/part.vz',
#  'part/part.px',
#  'part/part.py',
# ...
